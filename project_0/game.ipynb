# %%
from game_v2 import *

score_game(random_predict)
# Out:
# You predict the number! This number is 52, 8 attempt
# You predict the number! This number is 93, 113 attempt
# You predict the number! This number is 15, 29 attempt
# You predict the number! This number is 72, 16 attempt
# You predict the number! This number is 61, 149 attempt
# You predict the number! This number is 21, 181 attempt
# You predict the number! This number is 83, 18 attempt
# You predict the number! This number is 87, 45 attempt
# You predict the number! This number is 75, 322 attempt
# You predict the number! This number is 75, 16 attempt
# You predict the number! This number is 88, 77 attempt
# You predict the number! This number is 100, 99 attempt
# You predict the number! This number is 24, 36 attempt
# You predict the number! This number is 3, 24 attempt
# You predict the number! This number is 22, 294 attempt
# You predict the number! This number is 53, 325 attempt
# You predict the number! This number is 2, 32 attempt
# ...
